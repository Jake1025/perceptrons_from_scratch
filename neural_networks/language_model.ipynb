# %%
from datasets import load_dataset, load_from_disk

# %%
try: 
    ds = load_from_disk("../data/wikipedia_20231101_en")
except:
    print("Could not load dataset from disk, falling back to internet download.")
    ds = load_dataset("wikimedia/wikipedia", "20231101.en")
    ds.save_to_disk("../data/wikipedia_20231101_en")
# Out:
# Loading dataset from disk:   0%|          | 0/41 [00:00<?, ?it/s]
